# %% [markdown]
# # Pregunta 5:  ODE

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Ejercicio 1
# $y'= -5y+5t^2+2t$
# * $0 \le t \le 1$
# * $y(t_0)=1/3$
# * $N=10$

# %%
# %autoreload 2
from src import ODE_euler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=t^2 +1/3e^{-5t}$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %%
f = lambda t, y: -5 * y + 5 * t**2 + 2 * t

a, b = 0, 1
y_t0 = 1 / 3
N = 10

ys, ts, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

exact_sol = lambda t: t**2 + (1 / 3) * np.exp(-5 * t)

t_exact = np.linspace(a, b, 100)
y_exact = exact_sol(t_exact)

plt.plot(
    ts,
    ys,
    label="Aproximación de Euler: N = 10",
    marker="o",
    linestyle="--",
    color="blue",
)
plt.plot(t_exact, y_exact, label="Solución exacta", linestyle="-", color="red")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title(f"Método de Euler para la EDO\n$y' = -5y + 5t^2 + 2t$, h = {h}")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Errores
# Calcule el error relativo para diferentes valores de N.

# %% [markdown]
# ### a. $N = 10$

# %%
N = 10

ys1, ts, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

ts = np.array(ts)
y_real1 = exact_sol(ts)
error_rel_promedio = np.mean(np.abs((y_real1 - ys1) / y_real1))

print(f"Promedio del error relativo: {error_rel_promedio:.4e}")
# Out:
# Promedio del error relativo: 1.2910e-01

# %% [markdown]
# ### b. $N = 5$

# %%
N = 5

ys2, ts, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

ts = np.array(ts)
y_real2 = exact_sol(ts)
error_rel_promedio = np.mean(np.abs((y_real2 - ys2) / y_real2))

print(f"Promedio del error relativo: {error_rel_promedio:.4e}")
# Out:
# Promedio del error relativo: 2.7979e-01

# %% [markdown]
# ### c. $N = 20$

# %%
N = 20

ys3, ts, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

ts = np.array(ts)
y_real3 = exact_sol(ts)
error_rel_promedio = np.mean(np.abs((y_real3 - ys3) / y_real3))

print(f"Promedio del error relativo: {error_rel_promedio:.4e}")
# Out:
# Promedio del error relativo: 6.3146e-02
